# %% [markdown]
# # Notebook JUPYTER : PROJET DALI

# %% [markdown]
# ## Ouverture fichier DALI

# %%
import pickle

file_dali = 'DALI.pkl'

open_file = open(file_dali,'rb')

DALI_songs = pickle.load(open_file)

open_file.close()

# %%
## Base de données = DALI_songs ==> contient toutes les données des musiques

## Combient y a t-il de morceaux au total ?
elem = 0
for element in DALI_songs :
    elem = elem +1
print ('Il y a {} morceaux au total'.format(elem))

## Le type des attributs : 
liste = ['titre, artiste, album, date, popularite, duree, tempo, genres, langue, tuning']

ligne_1 = DALI_songs[0]
for e in range (0, len(ligne_1)) :
    print('Le type de l°attribut est : {}'.format(type (ligne_1[e])))
# Out:
# Il y a 12299 morceaux au total
# Le type de l°attribut est : <class 'str'>
# Le type de l°attribut est : <class 'str'>
# Le type de l°attribut est : <class 'str'>
# Le type de l°attribut est : <class 'int'>
# Le type de l°attribut est : <class 'float'>
# Le type de l°attribut est : <class 'int'>
# Le type de l°attribut est : <class 'int'>
# Le type de l°attribut est : <class 'list'>
# Le type de l°attribut est : <class 'str'>
# Le type de l°attribut est : <class 'numpy.float64'>

# %%
print (DALI_songs)
# Out:
# [['Dance Floor Anthem', 'Good Charlotte', 'Good Morning Revival', 2007, 0.633, 228, 126, ['Other'], 'english', -0.03], ['Calling All Skeletons', 'Alkaline Trio', 'Damnesia', 2008, 0.388, 202, 129, ['Alternative', 'Rock', 'Rock Indé/Pop Rock'], 'english', 0.0], ['Stay', 'Hurts', 'Happiness', 2010, 0.567, 235, 135, ['Pop'], 'english', -0.04], ['Mad House', 'Rihanna', 'Rated R', 2009, 0.583, 94, 135, ['Pop'], 'english', 0.03], ['Cruise Control', 'Headless Chickens', 'ChickensHits', 1991, 0.608, 260, 135, ['Alternative', 'Rock'], 'english', -0.05], ['Something In The Way You Move', 'Ellie Goulding', 'Something In The Way You Move', 2015, 0.592, 229, 109, ['Other'], 'english', -0.02], ['Wear My Kiss', 'Sugababes', 'Sweet 7', 2009, 0.462, 193, 126, ['Pop'], 'english', -0.17], ['Moje Jedyne Marzenie', 'Anna Jantar', 'Anna Jantar', 1991, 0.844, 217, 114, ['Pop'], 'polish', -0.22], ['Ashley', 'Escape The Fate', 'This War Is Ours', 2008, 0.849, 205, 117, ['Alternative'], 'english', 0.01], ['Le
# ...

# %% [markdown]
# ## Première partie : DALI et son contenu

# %%
longueur = 0

for element in DALI_songs : 
    for m in element :
        m = element[5]
    if m > longueur : 
        longueur = m  
    for t in element : 
        if titre == m :
            t = element
            titre = element[0]

print ('Le morceau {} a une durée de {}secondes'.format(titre,longueur))
# Out:
# Le morceau <class 'str'> a une durée de 600secondes
